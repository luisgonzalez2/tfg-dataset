# %% [markdown]
# ## Montar Google Drive en Colab y cargar los archivos CSV

# %%
from google.colab import drive
import pandas as pd

# Montar Google Drive en Colab y cargar el archivo CSV.
drive.mount('/content/drive')

file_path_1 = '/content/drive/My Drive/Colab Notebooks/checkpoint_1/1-poblacion-35-cluster.csv'
df_1 = pd.read_csv(file_path_1, sep=';', encoding='utf-8')

file_path_2 = '/content/drive/My Drive/Colab Notebooks/checkpoint_1/2-densidad-35-cluster.csv'
df_2 = pd.read_csv(file_path_2, sep=';', encoding='utf-8')

file_path_3 = '/content/drive/My Drive/Colab Notebook>s/checkpoint_1/3-distancia-35-cluster.csv'
df_3 = pd.read_csv(file_path_3, sep=';', encoding='utf-8')

file_path_4 = '/content/drive/My Drive/Colab Notebooks/4-zonas-estadisticas.csv'
df_4 = pd.read_csv(file_path_4, sep=';', encoding='ISO-8859-1')

file_path_5 = '/content/drive/My Drive/Colab Notebooks/checkpoint_2/5-pib.csv'
df_5 = pd.read_csv(file_path_5, sep=';', encoding='ISO-8859-1')

file_path_6 = '/content/drive/My Drive/Colab Notebooks/checkpoint_2/6-pib-capita.csv'
# Leer el archivo CSV en df_6, especificando que se utiliza un punto como separador de miles
df_6 = pd.read_csv(file_path_6, sep=';', encoding='ISO-8859-1', thousands='.')

file_path_7 = '/content/drive/My Drive/Colab Notebooks/checkpoint_2/7-unidades-productivas.csv'
df_7 = pd.read_csv(file_path_7, sep=';', encoding='utf-8')

file_path_8 = '/content/drive/My Drive/Colab Notebooks/checkpoint_2/8-empresas.csv'
df_8 = pd.read_csv(file_path_8, sep=';', encoding='ISO-8859-1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Variación de población / densidad / distancia a la capital con respecto a la media del cluster

# %%
dfs = [df_1, df_2, df_3]
df_names = ['Población', 'Densidad de población', 'Distancia a la capital']

for i, df in enumerate(dfs):
    print(f"\n{'*' * 50}")
    print(f"DataFrame: {df_names[i]}")
    print(f"{'*' * 50}\n")
    # Calcular la media del valor de Valor_Agrupacion para cada cluster
    mean_cluster_0 = df[df['Cluster'] == 0]['Valor_Agrupacion'].mean()
    mean_cluster_1 = df[df['Cluster'] == 1]['Valor_Agrupacion'].mean()
    mean_cluster_2 = df[df['Cluster'] == 2]['Valor_Agrupacion'].mean()
    mean_cluster_3 = df[df['Cluster'] == 3]['Valor_Agrupacion'].mean()

    print(f"Media Cluster 0: {mean_cluster_0}")
    print(f"Media Cluster 1: {mean_cluster_1}")
    print(f"Media Cluster 2: {mean_cluster_2}")
    print(f"Media Cluster 3: {mean_cluster_3}\n")

    # Añadir una nueva columna 'Variacion' que indique la variación de valor con
    # respecto al valor medio de su cluster
    df['Variacion'] = df.apply(lambda row: row['Valor_Agrupacion'] / [mean_cluster_0, mean_cluster_1, mean_cluster_2, mean_cluster_3][int(row['Cluster'])], axis=1)

    # Añadir una nueva columna 'Variacion_Porcentaje' que indique la variación
    # de valor en porcentaje
    df['Variacion_Porcentaje'] = df['Variacion'] * 100

    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])

    print(df.head())  # Imprimir los primeros registros para verificar
    print("\n\n")
# Out:
# **************************************************
# DataFrame: Población
# **************************************************
#
# Media Cluster 0: 7383.1
# Media Cluster 1: 27629.777777777777
# Media Cluster 2: 1363.9450549450548
# Media Cluster 3: 16238.714285714286
#
#   Tipo_Agrupacion  ID_Agrupacion  Nombre_Agrupacion  Valor_Agrupacion  \
# 0      Municipios             14       Acebeda (La)                55
# 1      Municipios             29            Ajalvir              4793
# 2      Municipios             35  Alameda del Valle               248
# 3      Municipios             40         Alamo (El)              9946
# 4      Municipios             88   Aldea del Fresno              3078
#
#    Cluster  Variacion  Variacion_Porcentaje
# 0        2   0.040324              4.032420
# 1        0   0.649185             64.918530
# 2        2   0.181826             18.182551
# 3        0   1.347131            134.713061
# 4        2   2.256689            225.668915
#
#
#
#
# **************************************************
# DataFrame: Densidad de población
# **************************************************
#
# Media Cluster 0: 49.83445544554456
# Media Cluster 1: 1218.7414285714287
# Media Cluster 2: 563.7292307692308
# Media Cluster 3: 260.78393939393936
#
#   Tipo_Agrupacion  ID_Agrupacion  Nombre_Agrupacion  Valor_Agrupacion  \
# 0      Municipios             14       Acebeda (La)              3.06
# 1      Municipios             29            Ajalvir            246.21
# 2      Municipios             35  Alameda del Valle             10.68
# 3      Municipios             40         Alamo (El)            467.88
# 4      Municipios             88   Aldea del Fresno             65.93
#
#    Cluster  Variacion  Variacion_Porcentaje
# 0        0   0.061403              6.140330
# 1        3   0.944115             94.411489
# 2        0   0.214310             21.430956
# 3        2   0.829973             82.997293
# 4        0   1.322980            132.298024
#
#
#
#
# **************************************************
# DataFrame: Distancia a la capital
# **************************************************
#
# Media Cluster 0: 86.09380000000002
# Media Cluster 1: 47.728227272727274
# Media Cluster 2: 61.4927027027027
# Media Cluster 3: 33.35507894736841
#
#   Tipo_Agrupacion  ID_Agrupacion  Nombre_Agrupacion  Valor_Agrupacion  \
# 0      Municipios             14       Acebeda (La)            88.477
# 1      Municipios             29            Ajalvir            34.911
# 2      Municipios             35  Alameda del Valle            92.242
# 3      Municipios             40         Alamo (El)            42.104
# 4      Municipios             88   Aldea del Fresno            56.001
#
#    Cluster  Variacion  Variacion_Porcentaje
# 0        0   1.027681            102.768144
# 1        3   1.046647            104.664720
# 2        0   1.071413            107.141281
# 3        1   0.882161             88.216140
# 4        2   0.910693             91.069342

# %% [markdown]
# ## Añadir indicadores

# %%
# Crear un nuevo DataFrame df_final
df_final = pd.DataFrame()

# Copiar las columnas de df_1 al nuevo DataFrame df_final
df_final['ID'] = df_1['ID_Agrupacion']
df_final['Municipio'] = df_1['Nombre_Agrupacion']
df_final['Poblacion'] = df_1['Valor_Agrupacion']
df_final['Variacion_Poblacion'] = df_1['Variacion_Porcentaje']
df_final['Cluster_Poblacion'] = df_1['Cluster']

# Asegurarse de que los DataFrames están ordenados por el nombre del municipio
df_final = df_final.sort_values('Municipio')
df_2 = df_2.sort_values('Nombre_Agrupacion')
df_3 = df_3.sort_values('Nombre_Agrupacion')
df_4 = df_4.sort_values('Nombre_Agrupacion')
df_5 = df_5.sort_values('Municipio')
df_6 = df_6.sort_values('Municipio')
df_7 = df_7.sort_values('Municipio')
df_8 = df_8.sort_values('Municipio')

# Comprobar si los nombres de los municipios coinciden en df_2, df_3 y df_4
if (df_final['Municipio'].values == df_2['Nombre_Agrupacion'].values).all() and (df_final['Municipio'].values == df_3['Nombre_Agrupacion'].values).all():
    # Si los nombres coinciden, copiar las columnas de df_2, df_3 y df_4
    df_final['Densidad'] = df_2['Valor_Agrupacion']
    df_final['Variacion_Densidad'] = df_2['Variacion_Porcentaje']
    df_final['Cluster_Densidad'] = df_2['Cluster']

    df_final['Distancia'] = df_3['Valor_Agrupacion']
    df_final['Variacion_Distancia'] = df_3['Variacion_Porcentaje']
    df_final['Cluster_Distancia'] = df_3['Cluster']

    df_final['Nuts4_codigo'] = df_4['nuts4_codigo']
    df_final['Nuts4_nombre'] = df_4['nuts4_nombre']
else:
    print("Los nombres de los municipios no coinciden en df_final, df_2 y df_3")

# Crear un DataFrame temporal con las columnas de df_5 y df_6
df_temp = df_5[['Municipio', '2015', '2016', '2017', '2018', '2019', '2020 (p)']].copy()
df_temp_2 = df_6[['Municipio', '2015', '2016', '2017', '2018', '2019', '2020 (p)']].copy()
df_temp_3 = df_7[['Municipio', '2015', '2016', '2017', '2018', '2019', '2020']].copy()
df_temp_4 = df_8.copy()

# Cambiar los nombres de las columnas en el df temporal
df_temp.columns = ['Municipio', 'pib_2015', 'pib_2016', 'pib_2017', 'pib_2018', 'pib_2019', 'pib_2020']
df_temp_2.columns = ['Municipio', 'pib_capita_2015', 'pib_capita_2016', 'pib_capita_2017', 'pib_capita_2018', 'pib_capita_2019', 'pib_capita_2020']
df_temp_3.columns = ['Municipio', 'u_productivas_2015', 'u_productivas_2016', 'u_productivas_2017', 'u_productivas_2018', 'u_productivas_2019', 'u_productivas_2020']
df_temp_4.columns = ['Municipio'] + ['nempresas_' + col.lower() for col in df_temp_4.columns[1:]]

# Reemplaza el espacio en blanco en los nombres de las columnas
df_temp_4.columns = df_temp_4.columns.str.replace(' ', '', regex=True)

# Iterar sobre los municipios en df_final
for i, municipio in enumerate(df_final['Municipio']):
    if municipio in df_temp['Municipio'].values:
        for year in ['pib_2015', 'pib_2016', 'pib_2017', 'pib_2018', 'pib_2019', 'pib_2020']:
            df_final.loc[i, year] = df_temp[df_temp['Municipio'] == municipio][year].values[0]
    if municipio in df_temp_2['Municipio'].values:
        for year in ['pib_capita_2015', 'pib_capita_2016', 'pib_capita_2017', 'pib_capita_2018', 'pib_capita_2019', 'pib_capita_2020']:
            df_final.loc[i, year] = df_temp_2[df_temp_2['Municipio'] == municipio][year].values[0]
    if municipio in df_temp_3['Municipio'].values:
        for year in ['u_productivas_2015', 'u_productivas_2016', 'u_productivas_2017', 'u_productivas_2018', 'u_productivas_2019', 'u_productivas_2020']:
            df_final.loc[i, year] = df_temp_3[df_temp_3['Municipio'] == municipio][year].values[0]
    if municipio in df_temp_4['Municipio'].values:
      for column in df_temp_4.columns[1:]:
        df_final.loc[i, column] = df_temp_4[df_temp_4['Municipio'] == municipio][column].values[0]

# Cambiar el separador de miles por un punto y el de decimales por una coma
for column in ['pib_capita_2015', 'pib_capita_2016', 'pib_capita_2017', 'pib_capita_2018',
               'pib_capita_2019', 'pib_capita_2020', 'Variacion_Poblacion', 'Variacion_Densidad',
               'Variacion_Distancia', 'u_productivas_2016', 'u_productivas_2017',
               'u_productivas_2018', 'u_productivas_2019', 'u_productivas_2020']:
    df_final[column] = df_final[column].apply(lambda x: '{:,.2f}'.format(x).replace(",", "x").replace(".", ",").replace("x", "."))

# Imprimir el contenido de df_final para verificar
print(df_final)
# Out:
#        ID              Municipio  Poblacion Variacion_Poblacion  \
# 0      14           Acebeda (La)         55                4,03
# 1      29                Ajalvir       4793               64,92
# 2      35      Alameda del Valle        248               18,18
# 3      40             Alamo (El)       9946              134,71
# 4      88       Aldea del Fresno       3078              225,67
# ..    ...                    ...        ...                 ...
# 149  1795        Villar del Olmo       2192              160,71
# 150  1809  Villarejo de Salvanés       7546              102,21
# 151  1816   Villaviciosa de Odón      28016              101,40
# 152  1821  Villavieja del Lozoya        280               20,53
# 153  1837              Zarzalejo       1771              129,84
#
#      Cluster_Poblacion  Densidad Variacion_Densidad  Cluster_Densidad  \
# 0                    2      3.06               6,14                 0
# 1                    0    246.21              94,41                 3
# 2                    2     10.68              21,43                 0
# 3                    0    467.88              83,00                 2
# 4                    2     65.93             132,30                 0
# ..                 ...       ...                ...               ...
# 149                  2     81.15             162,84                 0
# 150                  0     64.79             130,01                 0
# 151                  1    420.84              74,65                 2
# 152                  2     13.60              27,29                 0
# 153                  2     89.30             179,19                 0
#
#      Distancia Variacion_Distancia  ...  \
# 0       88.477              102,77  ...
# 1       34.911              104,66  ...
# 2       92.242              107,14  ...
# 3       42.104               88,22  ...
# 4       56.001               91,07  ...
# ..         ...                 ...  ...
# 149     48.941              102,54  ...
# 150     50.672              106,17  ...
# 151     26.157               78,42  ...
# 152     80.015               92,94  ...
# 153     65.280              106,16  ...
#
#      nempresas_otros_servicios_personales_2017  \
# 0                                          0.0
# 1                                          0.0
# 2                                          0.0
# 3                                         59.0
# 4                                          0.0
# ..                                         ...
# 149                                        0.0
# 150                                       47.0
# 151                                      257.0
# 152                                        0.0
# 153                                        0.0
#
#      nempresas_otros_servicios_personales_2018  \
# 0                                          0.0
# 1                                          0.0
# 2                                          0.0
# 3                                         64.0
# 4                                          0.0
# ..                                         ...
# 149                                        0.0
# 150                                       41.0
# 151                                      248.0
# 152                                        0.0
# 153                                        0.0
#
#     nempresas_otros_servicios_personales_2019  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.0
# 3                                        62.0
# 4                                         0.0
# ..                                        ...
# 149                                       0.0
# 150                                      38.0
# 151                                     251.0
# 152                                       0.0
# 153                                       0.0
#
#     nempresas_otros_servicios_personales_2020 nempresas_total_servicios_2015  \
# 0                                         0.0                            0.0
# 1                                         0.0                          161.0
# 2                                         0.0                            0.0
# 3                                        66.0                          207.0
# 4                                         0.0                           43.0
# ..                                        ...                            ...
# 149                                       0.0                           57.0
# 150                                      38.0                          127.0
# 151                                     277.0                         1666.0
# 152                                       0.0                            0.0
# 153                                       0.0                           29.0
#
#     nempresas_total_servicios_2016 nempresas_total_servicios_2017  \
# 0                              0.0                            0.0
# 1                            189.0                          196.0
# 2                              0.0                            0.0
# 3                            216.0                          240.0
# 4                             53.0                           58.0
# ..                             ...                            ...
# 149                           68.0                           75.0
# 150                          121.0                          123.0
# 151                         1772.0                         1812.0
# 152                            0.0                            0.0
# 153                           34.0                           39.0
#
#     nempresas_total_servicios_2018 nempresas_total_servicios_2019  \
# 0                              0.0                            0.0
# 1                            204.0                          204.0
# 2                              0.0                            0.0
# 3                            240.0                          245.0
# 4                             54.0                           61.0
# ..                             ...                            ...
# 149                           79.0                           87.0
# 150                          131.0                          117.0
# 151                         1846.0                         1893.0
# 152                            0.0                            0.0
# 153                           45.0                           53.0
#
#     nempresas_total_servicios_2020
# 0                              0.0
# 1                            211.0
# 2                              0.0
# 3                            255.0
# 4                             70.0
# ..                             ...
# 149                           95.0
# 150                          117.0
# 151                         1919.0
# 152                            0.0
# 153                           57.0
#
# [154 rows x 97 columns]

# %% [markdown]
# ## Variación de los indicadores con respecto a los clústeres a los que pertenecen

# %%
columnas = ['pib_2015', 'pib_2016', 'pib_2017', 'pib_2018', 'pib_2019', 'pib_2020',
            'pib_capita_2015', 'pib_capita_2016', 'pib_capita_2017', 'pib_capita_2018',
            'pib_capita_2019', 'pib_capita_2020', 'u_productivas_2015', 'u_productivas_2016', 'u_productivas_2017',
            'u_productivas_2018', 'u_productivas_2019', 'u_productivas_2020',
            'nempresas_total_2015', 'nempresas_total_2016', 'nempresas_total_2017',
            'nempresas_total_2018', 'nempresas_total_2019', 'nempresas_total_2020',
            'nempresas_b_e_industria_2015', 'nempresas_b_e_industria_2016',
            'nempresas_b_e_industria_2017', 'nempresas_b_e_industria_2018',
            'nempresas_b_e_industria_2019', 'nempresas_b_e_industria_2020',
            'nempresas_f_construccion_2015', 'nempresas_f_construccion_2016',
            'nempresas_f_construccion_2017', 'nempresas_f_construccion_2018',
            'nempresas_f_construccion_2019', 'nempresas_f_construccion_2020',
            'nempresas_comercio_transporte_hosteleria_2015',
            'nempresas_comercio_transporte_hosteleria_2016',
            'nempresas_comercio_transporte_hosteleria_2017',
            'nempresas_comercio_transporte_hosteleria_2018',
            'nempresas_comercio_transporte_hosteleria_2019',
            'nempresas_comercio_transporte_hosteleria_2020',
            'nempresas_j_informacion_comunicaciones_2015',
            'nempresas_j_informacion_comunicaciones_2016',
            'nempresas_j_informacion_comunicaciones_2017',
            'nempresas_j_informacion_comunicaciones_2018',
            'nempresas_j_informacion_comunicaciones_2019',
            'nempresas_j_informacion_comunicaciones_2020',
            'nempresas_k_actividades_financieras_seguros_2015',
            'nempresas_k_actividades_financieras_seguros_2016',
            'nempresas_k_actividades_financieras_seguros_2017',
            'nempresas_k_actividades_financieras_seguros_2018',
            'nempresas_k_actividades_financieras_seguros_2019',
            'nempresas_k_actividades_financieras_seguros_2020',
            'nempresas_l_actividades_inmobiliarias_2015',
            'nempresas_l_actividades_inmobiliarias_2016',
            'nempresas_l_actividades_inmobiliarias_2017',
            'nempresas_l_actividades_inmobiliarias_2018',
            'nempresas_l_actividades_inmobiliarias_2019',
            'nempresas_l_actividades_inmobiliarias_2020',
            'nempresas_actividades_profesionales_tecnicas_2015',
            'nempresas_actividades_profesionales_tecnicas_2016',
            'nempresas_actividades_profesionales_tecnicas_2017',
            'nempresas_actividades_profesionales_tecnicas_2018',
            'nempresas_actividades_profesionales_tecnicas_2019',
            'nempresas_actividades_profesionales_tecnicas_2020',
            'nempresas_educacion_sanidad_servicios_sociales_2015',
            'nempresas_educacion_sanidad_servicios_sociales_2016',
            'nempresas_educacion_sanidad_servicios_sociales_2017',
            'nempresas_educacion_sanidad_servicios_sociales_2018',
            'nempresas_educacion_sanidad_servicios_sociales_2019',
            'nempresas_educacion_sanidad_servicios_sociales_2020',
            'nempresas_otros_servicios_personales_2015',
            'nempresas_otros_servicios_personales_2016',
            'nempresas_otros_servicios_personales_2017',
            'nempresas_otros_servicios_personales_2018',
            'nempresas_otros_servicios_personales_2019',
            'nempresas_otros_servicios_personales_2020',
            'nempresas_total_servicios_2015', 'nempresas_total_servicios_2016',
            'nempresas_total_servicios_2017', 'nempresas_total_servicios_2018',
            'nempresas_total_servicios_2019', 'nempresas_total_servicios_2020']

# Mapear los valores de 'Nuts4_nombre' a números enteros
mapping = {'Este Metropolitano': 0, 'Municipio de Madrid': 1, 'Nordeste Comunidad': 2, 'Norte Metropolitano': 3, 'Oeste Metropolitano': 4, 'Sierra Central': 5, 'Sierra Norte': 6, 'Sierra Sur': 7, 'Sudeste Comunidad': 8, 'Sudoeste Comunidad': 9, 'Sur Metropolitano': 10}
df_final['Zona_Estadistica'] = df_final['Nuts4_nombre'].map(mapping)

df_medias_cluster = pd.DataFrame(columns=['Indicador', 'Tipo_agrupacion', 'Cluster', 'Media'])
clusters = ['Cluster_Poblacion', 'Cluster_Densidad', 'Cluster_Distancia', 'Zona_Estadistica']

for col in columnas:
    if df_final[col].dtype == 'object':  # Si la columna es de tipo string
        df_final[col] = df_final[col].str.replace('.', '').str.replace(',', '.').astype(float)

for col in columnas:
    for cluster in clusters:
        # Calcular la media del valor de la columna para cada cluster
        mean_cluster = df_final.groupby(cluster)[col].mean()

        print(f"\n{'*' * 50}")
        print(f"Media de '{col}' para {cluster}:")
        for i in range(len(mean_cluster)):
            if cluster == 'Zona_Estadistica':
                cluster_name = list(mapping.keys())[list(mapping.values()).index(i)]
            else:
                cluster_name = i
            print(f"Cluster {cluster_name}: {mean_cluster[i]}")
            df_medias_cluster = pd.concat([df_medias_cluster, pd.DataFrame({
                'Indicador': [col],
                'Tipo_agrupacion': [cluster.replace('Cluster_', '')],
                'Cluster': [cluster_name],
                'Media': [round(mean_cluster[i], 2)]  # Redondear a 2 decimales
            })], ignore_index=True)

        # Añadir una nueva columna que indique la variación del valor de la columna con respecto al valor medio de su cluster
        new_col = f'Variacion_{col}_{cluster}'
        df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)

        # Cambiar el separador de miles por un punto y el de decimales por una coma
        df_final[new_col] = df_final[new_col].apply(lambda x: '{:,.2f}'.format(x).replace(",", "x").replace(".", ",").replace("x", "."))

print(df_final.head())  # Imprimir los primeros registros para verificar
print(df_medias_cluster.head())  # Imprimir los primeros registros del nuevo DataFrame para verificar
# Out:
# **************************************************
# Media de 'pib_2015' para Cluster_Poblacion:
# Cluster 0: 125964.3
# Cluster 1: 440762.0
# Cluster 2: 19738.417582417584
# Cluster 3: 287148.4285714286
#
# **************************************************
# Media de 'pib_2015' para Cluster_Densidad:
# Cluster 0: 29377.51485148515
# Cluster 1: 358861.14285714284
# Cluster 2: 310719.23076923075
# Cluster 3: 160702.9393939394
#
# **************************************************
# Media de 'pib_2015' para Cluster_Distancia:
# Cluster 0: 15556.42857142857
# Cluster 1: 78257.15909090909
# Cluster 2: 46538.05405405405
# Cluster 3: 239789.63157894736
#
# **************************************************
# Media de 'pib_2015' para Zona_Estadistica:
# Cluster Este Metropolitano: 108447.66666666667
# Cluster Municipio de Madrid: 23842.0
# Cluster Nordeste Comunidad: 116706.22222222222
# Cluster Norte Metropolitano: 124767.85714285714
# Cluster Oeste Metropolitano: 161176.66666666666
# Cluster Sierra Central: 122641.8
# Cluster Sierra Norte: 96020.9268292683
# Cluster Sierra Sur: 59949.083333333336
# Cluster Sudeste Comunidad: 81838.80769230769
# Cluster Sudoeste Comunidad: 71776.14285714286
# Cluster Sur Metropolitano: 74451.18181818182
#
# **************************************************
# Media de 'pib_2016' para Cluster_Poblacion:
# Cluster 0: 131358.075
# Cluster 1: 479144.3333333333
# Cluster 2: 19983.69230769231
# Cluster 3: 300931.85714285716
#
# **************************************************
# Media de 'pib_2016' para Cluster_Densidad:
# Cluster 0: 30063.712871287127
# Cluster 1: 385268.4285714286
# Cluster 2: 330513.3076923077
# Cluster 3: 168733.24242424243
#
# **************************************************
# Media de 'pib_2016' para Cluster_Distancia:
# Cluster 0: 15771.57142857143
# Cluster 1: 80373.81818181818
# Cluster 2: 47776.27027027027
# Cluster 3: 256368.65789473685
#
# **************************************************
# Media de 'pib_2016' para Zona_Estadistica:
# Cluster Este Metropolitano: 112301.55555555556
# Cluster Municipio de Madrid: 23390.0
# Cluster Nordeste Comunidad: 127797.55555555556
# Cluster Norte Metropolitano: 128969.42857142857
# Cluster Oeste Metropolitano: 174034.66666666666
# Cluster Sierra Central: 130405.0
# Cluster Sierra Norte: 98993.41463414633
# Cluster Sierra Sur: 61766.166666666664
# Cluster Sudeste Comunidad: 86457.65384615384
# Cluster Sudoeste Comunidad: 76174.35714285714
# Cluster Sur Metropolitano: 79496.81818181818
#
# **************************************************
# Media de 'pib_2017' para Cluster_Poblacion:
# Cluster 0: 136901.575
# Cluster 1: 495435.77777777775
# Cluster 2: 20786.725274725275
# Cluster 3: 317932.85714285716
#
# **************************************************
# Media de 'pib_2017' para Cluster_Densidad:
# Cluster 0: 31116.653465346535
# Cluster 1: 410714.5714285714
# Cluster 2: 345689.6153846154
# Cluster 3: 174723.87878787878
#
# **************************************************
# Media de 'pib_2017' para Cluster_Distancia:
# Cluster 0: 15812.542857142857
# Cluster 1: 83044.22727272728
# Cluster 2: 49493.05405405405
# Cluster 3: 269447.6052631579
#
# **************************************************
# Media de 'pib_2017' para Zona_Estadistica:
# Cluster Este Metropolitano: 114988.33333333333
# Cluster Municipio de Madrid: 25711.0
# Cluster Nordeste Comunidad: 130094.66666666667
# Cluster Norte Metropolitano: 141106.85714285713
# Cluster Oeste Metropolitano: 175648.44444444444
# Cluster Sierra Central: 139316.13333333333
# Cluster Sierra Norte: 103939.51219512195
# Cluster Sierra Sur: 62394.666666666664
# Cluster Sudeste Comunidad: 90655.61538461539
# Cluster Sudoeste Comunidad: 79505.21428571429
# Cluster Sur Metropolitano: 82498.0
#
# **************************************************
# Media de 'pib_2018' para Cluster_Poblacion:
# Cluster 0: 139664.025
# Cluster 1: 516785.22222222225
# Cluster 2: 21435.20879120879
# Cluster 3: 330693.21428571426
# <ipython-input-28-f2a2ed251459>:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_medias_cluster = pd.concat([df_medias_cluster, pd.DataFrame({
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# **************************************************
# Media de 'pib_2018' para Cluster_Densidad:
# Cluster 0: 31735.19801980198
# Cluster 1: 427271.0
# Cluster 2: 362782.6923076923
# Cluster 3: 178957.87878787878
#
# **************************************************
# Media de 'pib_2018' para Cluster_Distancia:
# Cluster 0: 16075.685714285713
# Cluster 1: 86450.72727272728
# Cluster 2: 50614.86486486487
# Cluster 3: 278387.0
#
# **************************************************
# Media de 'pib_2018' para Zona_Estadistica:
# Cluster Este Metropolitano: 116657.22222222222
# Cluster Municipio de Madrid: 25211.0
# Cluster Nordeste Comunidad: 133726.22222222222
# Cluster Norte Metropolitano: 145420.85714285713
# Cluster Oeste Metropolitano: 180946.33333333334
# Cluster Sierra Central: 146809.86666666667
# Cluster Sierra Norte: 106699.0
# Cluster Sierra Sur: 66160.41666666667
# Cluster Sudeste Comunidad: 93050.19230769231
# Cluster Sudoeste Comunidad: 84350.57142857143
# Cluster Sur Metropolitano: 83806.09090909091
#
# **************************************************
# Media de 'pib_2019' para Cluster_Poblacion:
# Cluster 0: 146169.375
# Cluster 1: 549843.1111111111
# Cluster 2: 22195.472527472528
# Cluster 3: 354558.0
#
# **************************************************
# Media de 'pib_2019' para Cluster_Densidad:
# Cluster 0: 32881.316831683165
# Cluster 1: 464466.5714285714
# Cluster 2: 379678.6153846154
# Cluster 3: 190026.12121212122
#
# **************************************************
# Media de 'pib_2019' para Cluster_Distancia:
# Cluster 0: 16678.114285714284
# Cluster 1: 92371.18181818182
# Cluster 2: 52598.94594594595
# Cluster 3: 294335.15789473685
#
# **************************************************
# Media de 'pib_2019' para Zona_Estadistica:
# Cluster Este Metropolitano: 122932.11111111111
# Cluster Municipio de Madrid: 29309.0
# Cluster Nordeste Comunidad: 142354.44444444444
# Cluster Norte Metropolitano: 152491.14285714287
# Cluster Oeste Metropolitano: 193821.33333333334
# Cluster Sierra Central: 163077.26666666666
# Cluster Sierra Norte: 112020.51219512195
# Cluster Sierra Sur: 69756.5
# Cluster Sudeste Comunidad: 97374.26923076923
# Cluster Sudoeste Comunidad: 81626.21428571429
# Cluster Sur Metropolitano: 90879.0
#
# **************************************************
# Media de 'pib_2020' para Cluster_Poblacion:
# Cluster 0: 131628.525
# Cluster 1: 502023.1111111111
# Cluster 2: 20591.472527472528
# Cluster 3: 318148.28571428574
#
# **************************************************
# Media de 'pib_2020' para Cluster_Densidad:
# Cluster 0: 29991.287128712873
# Cluster 1: 418323.0
# Cluster 2: 347670.46153846156
# Cluster 3: 170731.87878787878
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# **************************************************
# Media de 'pib_2020' para Cluster_Distancia:
# Cluster 0: 15419.0
# Cluster 1: 84648.90909090909
# Cluster 2: 48409.43243243243
# Cluster 3: 264628.5
#
# **************************************************
# Media de 'pib_2020' para Zona_Estadistica:
# Cluster Este Metropolitano: 112770.55555555556
# Cluster Municipio de Madrid: 25853.0
# Cluster Nordeste Comunidad: 129017.11111111111
# Cluster Norte Metropolitano: 135778.0
# Cluster Oeste Metropolitano: 173347.33333333334
# Cluster Sierra Central: 148895.93333333332
# Cluster Sierra Norte: 101793.0243902439
# Cluster Sierra Sur: 63132.583333333336
# Cluster Sudeste Comunidad: 87983.46153846153
# Cluster Sudoeste Comunidad: 74544.78571428571
# Cluster Sur Metropolitano: 82090.36363636363
#
# **************************************************
# Media de 'pib_capita_2015' para Cluster_Poblacion:
# Cluster 0: 18403.925
# Cluster 1: 17934.666666666668
# Cluster 2: 21245.021978021978
# Cluster 3: 18201.14285714286
#
# **************************************************
# Media de 'pib_capita_2015' para Cluster_Densidad:
# Cluster 0: 20590.346534653465
# Cluster 1: 20064.571428571428
# Cluster 2: 18474.46153846154
# Cluster 3: 18952.636363636364
#
# **************************************************
# Media de 'pib_capita_2015' para Cluster_Distancia:
# Cluster 0: 29892.085714285713
# Cluster 1: 14215.363636363636
# Cluster 2: 17369.27027027027
# Cluster 3: 20297.894736842107
#
# **************************************************
# Media de 'pib_capita_2015' para Zona_Estadistica:
# Cluster Este Metropolitano: 18647.0
# Cluster Municipio de Madrid: 9684.0
# Cluster Nordeste Comunidad: 20015.777777777777
# Cluster Norte Metropolitano: 19664.285714285714
# Cluster Oeste Metropolitano: 14922.444444444445
# Cluster Sierra Central: 23313.866666666665
# Cluster Sierra Norte: 19766.975609756097
# Cluster Sierra Sur: 22367.583333333332
# Cluster Sudeste Comunidad: 18658.30769230769
# Cluster Sudoeste Comunidad: 20956.928571428572
# Cluster Sur Metropolitano: 22636.636363636364
#
# **************************************************
# Media de 'pib_capita_2016' para Cluster_Poblacion:
# Cluster 0: 19100.575
# Cluster 1: 19196.11111111111
# Cluster 2: 21895.065934065933
# Cluster 3: 19003.85714285714
#
# **************************************************
# Media de 'pib_capita_2016' para Cluster_Densidad:
# Cluster 0: 21270.970297029704
# Cluster 1: 21104.285714285714
# Cluster 2: 19405.46153846154
# Cluster 3: 19603.757575757576
#
# **************************************************
# Media de 'pib_capita_2016' para Cluster_Distancia:
# Cluster 0: 31526.4
# Cluster 1: 14341.477272727272
# Cluster 2: 17612.37837837838
# Cluster 3: 21294.36842105263
#
# **************************************************
# Media de 'pib_capita_2016' para Zona_Estadistica:
# Cluster Este Metropolitano: 18811.555555555555
# Cluster Municipio de Madrid: 9653.0
# Cluster Nordeste Comunidad: 22540.666666666668
# Cluster Norte Metropolitano: 20399.571428571428
# Cluster Oeste Metropolitano: 15731.333333333334
# Cluster Sierra Central: 24328.466666666667
# Cluster Sierra Norte: 20340.756097560974
# Cluster Sierra Sur: 22463.916666666668
# Cluster Sudeste Comunidad: 19419.69230769231
# Cluster Sudoeste Comunidad: 21133.428571428572
# Cluster Sur Metropolitano: 23622.363636363636
#
# **************************************************
# Media de 'pib_capita_2017' para Cluster_Poblacion:
# Cluster 0: 19778.25
# Cluster 1: 19550.555555555555
# Cluster 2: 22296.813186813186
# Cluster 3: 19930.071428571428
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# **************************************************
# Media de 'pib_capita_2017' para Cluster_Densidad:
# Cluster 0: 21650.158415841583
# Cluster 1: 22267.0
# Cluster 2: 20139.384615384617
# Cluster 3: 20326.333333333332
#
# **************************************************
# Media de 'pib_capita_2017' para Cluster_Distancia:
# Cluster 0: 31536.6
# Cluster 1: 14549.613636363636
# Cluster 2: 18476.72972972973
# Cluster 3: 22302.973684210527
#
# **************************************************
# Media de 'pib_capita_2017' para Zona_Estadistica:
# Cluster Este Metropolitano: 19262.444444444445
# Cluster Municipio de Madrid: 10524.0
# Cluster Nordeste Comunidad: 22968.88888888889
# Cluster Norte Metropolitano: 22399.85714285714
# Cluster Oeste Metropolitano: 15868.333333333334
# Cluster Sierra Central: 25049.4
# Cluster Sierra Norte: 21311.60975609756
# Cluster Sierra Sur: 19314.166666666668
# Cluster Sudeste Comunidad: 20009.615384615383
# Cluster Sudoeste Comunidad: 22248.5
# Cluster Sur Metropolitano: 24716.363636363636
#
# **************************************************
# Media de 'pib_capita_2018' para Cluster_Poblacion:
# Cluster 0: 19850.075
# Cluster 1: 20011.777777777777
# Cluster 2: 23049.46153846154
# Cluster 3: 20579.285714285714
#
# **************************************************
# Media de 'pib_capita_2018' para Cluster_Densidad:
# Cluster 0: 22294.29702970297
# Cluster 1: 22895.0
# Cluster 2: 20876.0
# Cluster 3: 20495.242424242424
#
# **************************************************
# Media de 'pib_capita_2018' para Cluster_Distancia:
# Cluster 0: 32377.6
# Cluster 1: 14713.386363636364
# Cluster 2: 19490.54054054054
# Cluster 3: 22578.026315789473
#
# **************************************************
# Media de 'pib_capita_2018' para Zona_Estadistica:
# Cluster Este Metropolitano: 18742.0
# Cluster Municipio de Madrid: 9693.0
# Cluster Nordeste Comunidad: 24046.222222222223
# Cluster Norte Metropolitano: 22892.85714285714
# Cluster Oeste Metropolitano: 15691.666666666666
# Cluster Sierra Central: 25374.6
# Cluster Sierra Norte: 21738.121951219513
# Cluster Sierra Sur: 21311.333333333332
# Cluster Sudeste Comunidad: 20664.076923076922
# Cluster Sudoeste Comunidad: 23669.071428571428
# Cluster Sur Metropolitano: 24291.545454545456
#
# **************************************************
# Media de 'pib_capita_2019' para Cluster_Poblacion:
# Cluster 0: 20377.0
# Cluster 1: 20763.11111111111
# Cluster 2: 22614.45054945055
# Cluster 3: 21720.571428571428
#
# **************************************************
# Media de 'pib_capita_2019' para Cluster_Densidad:
# Cluster 0: 21913.257425742573
# Cluster 1: 24180.571428571428
# Cluster 2: 21670.923076923078
# Cluster 3: 21203.81818181818
#
# **************************************************
# Media de 'pib_capita_2019' para Cluster_Distancia:
# Cluster 0: 31288.514285714286
# Cluster 1: 15114.977272727272
# Cluster 2: 19397.72972972973
# Cluster 3: 23317.842105263157
#
# **************************************************
# Media de 'pib_capita_2019' para Zona_Estadistica:
# Cluster Este Metropolitano: 19289.666666666668
# Cluster Municipio de Madrid: 11230.0
# Cluster Nordeste Comunidad: 23912.0
# Cluster Norte Metropolitano: 23695.285714285714
# Cluster Oeste Metropolitano: 15707.777777777777
# Cluster Sierra Central: 25180.066666666666
# Cluster Sierra Norte: 21172.878048780487
# Cluster Sierra Sur: 21506.5
# Cluster Sudeste Comunidad: 21146.884615384617
# Cluster Sudoeste Comunidad: 23396.428571428572
# Cluster Sur Metropolitano: 25039.363636363636
#
# **************************************************
# Media de 'pib_capita_2020' para Cluster_Poblacion:
# Cluster 0: 18101.25
# Cluster 1: 18577.444444444445
# Cluster 2: 20454.296703296703
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# Cluster 3: 19167.928571428572
#
# **************************************************
# Media de 'pib_capita_2020' para Cluster_Densidad:
# Cluster 0: 19759.574257425742
# Cluster 1: 21179.571428571428
# Cluster 2: 19387.46153846154
# Cluster 3: 18937.21212121212
#
# **************************************************
# Media de 'pib_capita_2020' para Cluster_Distancia:
# Cluster 0: 28029.342857142856
# Cluster 1: 13470.113636363636
# Cluster 2: 17857.35135135135
# Cluster 3: 20697.5
#
# **************************************************
# Media de 'pib_capita_2020' para Zona_Estadistica:
# Cluster Este Metropolitano: 17587.333333333332
# Cluster Municipio de Madrid: 9804.0
# Cluster Nordeste Comunidad: 20957.11111111111
# Cluster Norte Metropolitano: 21817.14285714286
# Cluster Oeste Metropolitano: 14297.333333333334
# Cluster Sierra Central: 22413.866666666665
# Cluster Sierra Norte: 18946.756097560974
# Cluster Sierra Sur: 19856.083333333332
# Cluster Sudeste Comunidad: 19130.19230769231
# Cluster Sudoeste Comunidad: 20406.5
# Cluster Sur Metropolitano: 22587.727272727272
#
# **************************************************
# Media de 'u_productivas_2015' para Cluster_Poblacion:
# Cluster 0: 687.025
# Cluster 1: 2547.0
# Cluster 2: 115.20879120879121
# Cluster 3: 1570.9285714285713
#
# **************************************************
# Media de 'u_productivas_2015' para Cluster_Densidad:
# Cluster 0: 179.07920792079207
# Cluster 1: 2083.285714285714
# Cluster 2: 1681.4615384615386
# Cluster 3: 859.1515151515151
#
# **************************************************
# Media de 'u_productivas_2015' para Cluster_Distancia:
# Cluster 0: 85.0
# Cluster 1: 485.02272727272725
# Cluster 2: 279.3783783783784
# Cluster 3: 1269.157894736842
#
# **************************************************
# Media de 'u_productivas_2015' para Zona_Estadistica:
# Cluster Este Metropolitano: 675.0
# Cluster Municipio de Madrid: 155.0
# Cluster Nordeste Comunidad: 713.8888888888889
# Cluster Norte Metropolitano: 592.8571428571429
# Cluster Oeste Metropolitano: 1012.0
# Cluster Sierra Central: 601.6666666666666
# Cluster Sierra Norte: 542.439024390244
# Cluster Sierra Sur: 347.5833333333333
# Cluster Sudeste Comunidad: 478.7307692307692
# Cluster Sudoeste Comunidad: 303.5
# Cluster Sur Metropolitano: 439.6363636363636
#
# **************************************************
# Media de 'u_productivas_2016' para Cluster_Poblacion:
# Cluster 0: 704.175
# Cluster 1: 2636.222222222222
# Cluster 2: 118.08791208791209
# Cluster 3: 1608.142857142857
#
# **************************************************
# Media de 'u_productivas_2016' para Cluster_Densidad:
# Cluster 0: 182.21782178217822
# Cluster 1: 2129.714285714286
# Cluster 2: 1741.3076923076924
# Cluster 3: 884.969696969697
#
# **************************************************
# Media de 'u_productivas_2016' para Cluster_Distancia:
# Cluster 0: 84.97142857142858
# Cluster 1: 498.8636363636364
# Cluster 2: 283.2162162162162
# Cluster 3: 1309.2105263157894
#
# **************************************************
# Media de 'u_productivas_2016' para Zona_Estadistica:
# Cluster Este Metropolitano: 698.8888888888889
# Cluster Municipio de Madrid: 173.0
# Cluster Nordeste Comunidad: 735.4444444444445
# Cluster Norte Metropolitano: 609.0
# Cluster Oeste Metropolitano: 1037.0
# Cluster Sierra Central: 630.6666666666666
# Cluster Sierra Norte: 553.1951219512196
# Cluster Sierra Sur: 361.5833333333333
# Cluster Sudeste Comunidad: 490.03846153846155
# Cluster Sudoeste Comunidad: 306.57142857142856
# Cluster Sur Metropolitano: 451.09090909090907
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# **************************************************
# Media de 'u_productivas_2017' para Cluster_Poblacion:
# Cluster 0: 709.55
# Cluster 1: 2672.6666666666665
# Cluster 2: 119.52747252747253
# Cluster 3: 1633.642857142857
#
# **************************************************
# Media de 'u_productivas_2017' para Cluster_Densidad:
# Cluster 0: 183.34653465346534
# Cluster 1: 2179.714285714286
# Cluster 2: 1757.923076923077
# Cluster 3: 895.6060606060606
#
# **************************************************
# Media de 'u_productivas_2017' para Cluster_Distancia:
# Cluster 0: 84.17142857142858
# Cluster 1: 505.52272727272725
# Cluster 2: 285.7027027027027
# Cluster 3: 1326.9473684210527
#
# **************************************************
# Media de 'u_productivas_2017' para Zona_Estadistica:
# Cluster Este Metropolitano: 697.7777777777778
# Cluster Municipio de Madrid: 180.0
# Cluster Nordeste Comunidad: 750.7777777777778
# Cluster Norte Metropolitano: 616.5714285714286
# Cluster Oeste Metropolitano: 1050.3333333333333
# Cluster Sierra Central: 645.6
# Cluster Sierra Norte: 557.9024390243902
# Cluster Sierra Sur: 366.0833333333333
# Cluster Sudeste Comunidad: 494.7692307692308
# Cluster Sudoeste Comunidad: 309.64285714285717
# Cluster Sur Metropolitano: 458.90909090909093
#
# **************************************************
# Media de 'u_productivas_2018' para Cluster_Poblacion:
# Cluster 0: 718.025
# Cluster 1: 2728.4444444444443
# Cluster 2: 122.17582417582418
# Cluster 3: 1657.5714285714287
#
# **************************************************
# Media de 'u_productivas_2018' para Cluster_Densidad:
# Cluster 0: 185.24752475247524
# Cluster 1: 2217.5714285714284
# Cluster 2: 1797.8461538461538
# Cluster 3: 908.969696969697
#
# **************************************************
# Media de 'u_productivas_2018' para Cluster_Distancia:
# Cluster 0: 85.31428571428572
# Cluster 1: 516.1590909090909
# Cluster 2: 287.4594594594595
# Cluster 3: 1349.157894736842
#
# **************************************************
# Media de 'u_productivas_2018' para Zona_Estadistica:
# Cluster Este Metropolitano: 714.8888888888889
# Cluster Municipio de Madrid: 174.0
# Cluster Nordeste Comunidad: 764.2222222222222
# Cluster Norte Metropolitano: 621.2857142857143
# Cluster Oeste Metropolitano: 1061.5555555555557
# Cluster Sierra Central: 666.2666666666667
# Cluster Sierra Norte: 567.0975609756098
# Cluster Sierra Sur: 369.75
# Cluster Sudeste Comunidad: 500.8076923076923
# Cluster Sudoeste Comunidad: 316.42857142857144
# Cluster Sur Metropolitano: 461.72727272727275
#
# **************************************************
# Media de 'u_productivas_2019' para Cluster_Poblacion:
# Cluster 0: 729.925
# Cluster 1: 2819.222222222222
# Cluster 2: 125.26373626373626
# Cluster 3: 1702.7142857142858
#
# **************************************************
# Media de 'u_productivas_2019' para Cluster_Densidad:
# Cluster 0: 189.68316831683168
# Cluster 1: 2274.8571428571427
# Cluster 2: 1850.923076923077
# Cluster 3: 929.1818181818181
#
# **************************************************
# Media de 'u_productivas_2019' para Cluster_Distancia:
# Cluster 0: 86.45714285714286
# Cluster 1: 531.2727272727273
# Cluster 2: 294.4864864864865
# Cluster 3: 1381.8157894736842
#
# **************************************************
# Media de 'u_productivas_2019' para Zona_Estadistica:
# Cluster Este Metropolitano: 737.0
# Cluster Municipio de Madrid: 184.0
# Cluster Nordeste Comunidad: 786.3333333333334
# Cluster Norte Metropolitano: 632.5714285714286
# Cluster Oeste Metropolitano: 1088.6666666666667
# Cluster Sierra Central: 693.8666666666667
# Cluster Sierra Norte: 580.5121951219512
# Cluster Sierra Sur: 380.5833333333333
# Cluster Sudeste Comunidad: 510.7692307692308
# Cluster Sudoeste Comunidad: 319.85714285714283
# Cluster Sur Metropolitano: 468.45454545454544
#
# **************************************************
# Media de 'u_productivas_2020' para Cluster_Poblacion:
# Cluster 0: 734.45
# Cluster 1: 2831.6666666666665
# Cluster 2: 126.58241758241758
# Cluster 3: 1716.9285714285713
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# ...
# Cluster 2: 743.8461538461538
# Cluster 3: 324.8787878787879
#
# **************************************************
# Media de 'nempresas_total_servicios_2018' para Cluster_Distancia:
# Cluster 0: 13.085714285714285
# Cluster 1: 201.4318181818182
# Cluster 2: 85.4054054054054
# Cluster 3: 461.86842105263156
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# **************************************************
# Media de 'nempresas_total_servicios_2018' para Zona_Estadistica:
# Cluster Este Metropolitano: 286.6666666666667
# Cluster Municipio de Madrid: 66.0
# Cluster Nordeste Comunidad: 321.22222222222223
# Cluster Norte Metropolitano: 197.57142857142858
# Cluster Oeste Metropolitano: 467.44444444444446
# Cluster Sierra Central: 219.4
# Cluster Sierra Norte: 162.6829268292683
# Cluster Sierra Sur: 124.5
# Cluster Sudeste Comunidad: 178.96153846153845
# Cluster Sudoeste Comunidad: 92.21428571428571
# Cluster Sur Metropolitano: 136.9090909090909
#
# **************************************************
# Media de 'nempresas_total_servicios_2019' para Cluster_Poblacion:
# Cluster 0: 233.575
# Cluster 1: 1182.0
# Cluster 2: 28.967032967032967
# Cluster 3: 623.3571428571429
#
# **************************************************
# Media de 'nempresas_total_servicios_2019' para Cluster_Densidad:
# Cluster 0: 48.663366336633665
# Cluster 1: 742.7142857142857
# Cluster 2: 773.5384615384615
# Cluster 3: 338.6060606060606
#
# **************************************************
# Media de 'nempresas_total_servicios_2019' para Cluster_Distancia:
# Cluster 0: 14.285714285714286
# Cluster 1: 211.86363636363637
# Cluster 2: 90.97297297297297
# Cluster 3: 477.7894736842105
#
# **************************************************
# Media de 'nempresas_total_servicios_2019' para Zona_Estadistica:
# Cluster Este Metropolitano: 300.1111111111111
# Cluster Municipio de Madrid: 68.0
# Cluster Nordeste Comunidad: 334.3333333333333
# Cluster Norte Metropolitano: 202.57142857142858
# Cluster Oeste Metropolitano: 489.44444444444446
# Cluster Sierra Central: 231.13333333333333
# Cluster Sierra Norte: 170.0487804878049
# Cluster Sierra Sur: 132.58333333333334
# Cluster Sudeste Comunidad: 185.3846153846154
# Cluster Sudoeste Comunidad: 94.0
# Cluster Sur Metropolitano: 143.36363636363637
#
# **************************************************
# Media de 'nempresas_total_servicios_2020' para Cluster_Poblacion:
# Cluster 0: 246.35
# Cluster 1: 1235.3333333333333
# Cluster 2: 30.956043956043956
# Cluster 3: 648.7142857142857
#
# **************************************************
# Media de 'nempresas_total_servicios_2020' para Cluster_Densidad:
# Cluster 0: 51.59405940594059
# Cluster 1: 780.2857142857143
# Cluster 2: 804.3846153846154
# Cluster 3: 355.7878787878788
#
# **************************************************
# Media de 'nempresas_total_servicios_2020' para Cluster_Distancia:
# Cluster 0: 15.0
# Cluster 1: 221.5
# Cluster 2: 98.27027027027027
# Cluster 3: 499.05263157894734
#
# **************************************************
# Media de 'nempresas_total_servicios_2020' para Zona_Estadistica:
# Cluster Este Metropolitano: 319.44444444444446
# Cluster Municipio de Madrid: 74.0
# Cluster Nordeste Comunidad: 348.6666666666667
# Cluster Norte Metropolitano: 214.28571428571428
# Cluster Oeste Metropolitano: 515.5555555555555
# Cluster Sierra Central: 244.66666666666666
# Cluster Sierra Norte: 175.6829268292683
# Cluster Sierra Sur: 141.33333333333334
# Cluster Sudeste Comunidad: 192.42307692307693
# Cluster Sudoeste Comunidad: 102.71428571428571
# Cluster Sur Metropolitano: 148.54545454545453
#    ID          Municipio  Poblacion Variacion_Poblacion  Cluster_Poblacion  \
# 0  14       Acebeda (La)         55                4,03                  2
# 1  29            Ajalvir       4793               64,92                  0
# 2  35  Alameda del Valle        248               18,18                  2
# 3  40         Alamo (El)       9946              134,71                  0
# 4  88   Aldea del Fresno       3078              225,67                  2
#
#    Densidad Variacion_Densidad  Cluster_Densidad  Distancia  \
# 0      3.06               6,14                 0     88.477
# 1    246.21              94,41                 3     34.911
# 2     10.68              21,43                 0     92.242
# 3    467.88              83,00                 2     42.104
# 4     65.93             132,30                 0     56.001
#
#   Variacion_Distancia  ...  \
# 0              102,77  ...
# 1              104,66  ...
# 2              107,14  ...
# 3               88,22  ...
# 4               91,07  ...
#
#    Variacion_nempresas_total_servicios_2018_Cluster_Distancia  \
# 0                                               0,00
# 1                                               0,44
# 2                                               0,00
# 3                                               1,19
# 4                                               0,63
#
#    Variacion_nempresas_total_servicios_2018_Zona_Estadistica  \
# 0                                               0,00
# 1                                               0,71
# 2                                               0,00
# 3                                               2,60
# 4                                               0,19
#
#   Variacion_nempresas_total_servicios_2019_Cluster_Poblacion  \
# 0                                               0,00
# 1                                               0,87
# 2                                               0,00
# 3                                               1,05
# 4                                               2,11
#
#    Variacion_nempresas_total_servicios_2019_Cluster_Densidad  \
# 0                                               0,00
# 1                                               0,60
# 2                                               0,00
# 3                                               0,32
# 4                                               1,25
#
#    Variacion_nempresas_total_servicios_2019_Cluster_Distancia  \
# 0                                               0,00
# 1                                               0,43
# 2                                               0,00
# 3                                               1,16
# 4                                               0,67
#
#    Variacion_nempresas_total_servicios_2019_Zona_Estadistica  \
# 0                                               0,00
# 1                                               0,68
# 2                                               0,00
# 3                                               2,61
# 4                                               0,20
#
#    Variacion_nempresas_total_servicios_2020_Cluster_Poblacion  \
# 0                                               0,00
# 1                                               0,86
# 2                                               0,00
# 3                                               1,04
# 4                                               2,26
#
#    Variacion_nempresas_total_servicios_2020_Cluster_Densidad  \
# 0                                               0,00
# 1                                               0,59
# 2                                               0,00
# 3                                               0,32
# 4                                               1,36
#
#    Variacion_nempresas_total_servicios_2020_Cluster_Distancia  \
# 0                                               0,00
# 1                                               0,42
# 2                                               0,00
# 3                                               1,15
# 4                                               0,71
#
#    Variacion_nempresas_total_servicios_2020_Zona_Estadistica
# 0                                               0,00
# 1                                               0,66
# 2                                               0,00
# 3                                               2,48
# 4                                               0,22
#
# [5 rows x 434 columns]
#   Indicador Tipo_agrupacion Cluster      Media
# 0  pib_2015       Poblacion       0  125964.30
# 1  pib_2015       Poblacion       1  440762.00
# 2  pib_2015       Poblacion       2   19738.42
# 3  pib_2015       Poblacion       3  287148.43
# 4  pib_2015        Densidad       0   29377.51
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)
# <ipython-input-28-f2a2ed251459>:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final.apply(lambda row: row[col] / mean_cluster[int(row[cluster])] if mean_cluster[int(row[cluster])] != 0 else 0, axis=1)

# %% [markdown]
# ## Variación de los indicadores con respecto a la media de la Comunidad de Madrid

# %%
columnas = ['pib_2015', 'pib_2016', 'pib_2017', 'pib_2018', 'pib_2019', 'pib_2020',
            'pib_capita_2015', 'pib_capita_2016', 'pib_capita_2017', 'pib_capita_2018',
            'pib_capita_2019', 'pib_capita_2020', 'u_productivas_2015', 'u_productivas_2016', 'u_productivas_2017',
            'u_productivas_2018', 'u_productivas_2019', 'u_productivas_2020',
            'nempresas_total_2015', 'nempresas_total_2016', 'nempresas_total_2017',
            'nempresas_total_2018', 'nempresas_total_2019', 'nempresas_total_2020',
            'nempresas_b_e_industria_2015', 'nempresas_b_e_industria_2016',
            'nempresas_b_e_industria_2017', 'nempresas_b_e_industria_2018',
            'nempresas_b_e_industria_2019', 'nempresas_b_e_industria_2020',
            'nempresas_f_construccion_2015', 'nempresas_f_construccion_2016',
            'nempresas_f_construccion_2017', 'nempresas_f_construccion_2018',
            'nempresas_f_construccion_2019', 'nempresas_f_construccion_2020',
            'nempresas_comercio_transporte_hosteleria_2015',
            'nempresas_comercio_transporte_hosteleria_2016',
            'nempresas_comercio_transporte_hosteleria_2017',
            'nempresas_comercio_transporte_hosteleria_2018',
            'nempresas_comercio_transporte_hosteleria_2019',
            'nempresas_comercio_transporte_hosteleria_2020',
            'nempresas_j_informacion_comunicaciones_2015',
            'nempresas_j_informacion_comunicaciones_2016',
            'nempresas_j_informacion_comunicaciones_2017',
            'nempresas_j_informacion_comunicaciones_2018',
            'nempresas_j_informacion_comunicaciones_2019',
            'nempresas_j_informacion_comunicaciones_2020',
            'nempresas_k_actividades_financieras_seguros_2015',
            'nempresas_k_actividades_financieras_seguros_2016',
            'nempresas_k_actividades_financieras_seguros_2017',
            'nempresas_k_actividades_financieras_seguros_2018',
            'nempresas_k_actividades_financieras_seguros_2019',
            'nempresas_k_actividades_financieras_seguros_2020',
            'nempresas_l_actividades_inmobiliarias_2015',
            'nempresas_l_actividades_inmobiliarias_2016',
            'nempresas_l_actividades_inmobiliarias_2017',
            'nempresas_l_actividades_inmobiliarias_2018',
            'nempresas_l_actividades_inmobiliarias_2019',
            'nempresas_l_actividades_inmobiliarias_2020',
            'nempresas_actividades_profesionales_tecnicas_2015',
            'nempresas_actividades_profesionales_tecnicas_2016',
            'nempresas_actividades_profesionales_tecnicas_2017',
            'nempresas_actividades_profesionales_tecnicas_2018',
            'nempresas_actividades_profesionales_tecnicas_2019',
            'nempresas_actividades_profesionales_tecnicas_2020',
            'nempresas_educacion_sanidad_servicios_sociales_2015',
            'nempresas_educacion_sanidad_servicios_sociales_2016',
            'nempresas_educacion_sanidad_servicios_sociales_2017',
            'nempresas_educacion_sanidad_servicios_sociales_2018',
            'nempresas_educacion_sanidad_servicios_sociales_2019',
            'nempresas_educacion_sanidad_servicios_sociales_2020',
            'nempresas_otros_servicios_personales_2015',
            'nempresas_otros_servicios_personales_2016',
            'nempresas_otros_servicios_personales_2017',
            'nempresas_otros_servicios_personales_2018',
            'nempresas_otros_servicios_personales_2019',
            'nempresas_otros_servicios_personales_2020',
            'nempresas_total_servicios_2015', 'nempresas_total_servicios_2016',
            'nempresas_total_servicios_2017', 'nempresas_total_servicios_2018',
            'nempresas_total_servicios_2019', 'nempresas_total_servicios_2020']

# Mapear los valores de 'Nuts4_nombre' a números enteros
mapping = {'Este Metropolitano': 0, 'Municipio de Madrid': 1, 'Nordeste Comunidad': 2, 'Norte Metropolitano': 3, 'Oeste Metropolitano': 4, 'Sierra Central': 5, 'Sierra Norte': 6, 'Sierra Sur': 7, 'Sudeste Comunidad': 8, 'Sudoeste Comunidad': 9, 'Sur Metropolitano': 10}
df_final['Zona_Estadistica'] = df_final['Nuts4_nombre'].map(mapping)

df_medias_comunidad = pd.DataFrame(columns=['Indicador', 'Media'])

for col in columnas:
    if df_final[col].dtype == 'object':  # Si la columna es de tipo string
        df_final[col] = df_final[col].str.replace('.', '').str.replace(',', '.').astype(float)

    # Calcular la media del valor de la columna para todos los municipios
    mean_total = df_final[col].mean()

    print(f"\n{'*' * 50}")
    print(f"Media de '{col}' para todos los municipios:")
    print(f"{mean_total}")
    print(f"{'*' * 50}\n")

    # Guardar la media en el DataFrame df_medias_comunidad
    df_medias_comunidad = pd.concat([df_medias_comunidad, pd.DataFrame({
        'Indicador': [col],
        'Media': [round(mean_total, 2)]  # Redondear a 2 decimales
    })], ignore_index=True)

    # Añadir una nueva columna que indique la variación del valor de la columna con respecto al valor medio de todos los municipios
    new_col = f'Variacion_{col}_totalcomunidad'
    df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0

    # Cambiar el separador de miles por un punto y el de decimales por una coma
    df_final[new_col] = df_final[new_col].apply(lambda x: '{:,.2f}'.format(x).replace(",", "x").replace(".", ",").replace("x", "."))

print(df_final.head())  # Imprimir los primeros registros para verificar
print(df_medias_comunidad.head())  # Imprimir los primeros registros del nuevo DataFrame para verificar
# Out:
# <ipython-input-29-c16a39c97c1e>:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_medias_comunidad = pd.concat([df_medias_comunidad, pd.DataFrame({
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# **************************************************
# Media de 'pib_2015' para todos los municipios:
# 96244.83116883117
# **************************************************
#
#
# **************************************************
# Media de 'pib_2016' para todos los municipios:
# 101286.90909090909
# **************************************************
#
#
# **************************************************
# Media de 'pib_2017' para todos los municipios:
# 105698.94155844155
# **************************************************
#
#
# **************************************************
# Media de 'pib_2018' para todos los municipios:
# 109207.38311688312
# **************************************************
#
#
# **************************************************
# Media de 'pib_2019' para todos los municipios:
# 115447.81168831169
# **************************************************
#
#
# **************************************************
# Media de 'pib_2020' para todos los municipios:
# 104618.5
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2015' para todos los municipios:
# 20036.896103896102
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2016' para todos los municipios:
# 20748.655844155845
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2017' para todos los municipios:
# 21266.987012987014
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2018' para todos los municipios:
# 21816.363636363636
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2019' para todos los municipios:
# 21843.83766233766
# **************************************************
#
#
# **************************************************
# Media de 'pib_capita_2020' para todos los municipios:
# 19616.487012987014
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2015' para todos los municipios:
# 538.1883116883117
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2016' para todos los municipios:
# 552.9415584415584
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2017' para todos los municipios:
# 559.6363636363636
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2018' para todos los municipios:
# 568.8376623376623
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2019' para todos los municipios:
# 583.1623376623377
# **************************************************
#
#
# **************************************************
# Media de 'u_productivas_2020' para todos los municipios:
# 587.1363636363636
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2015' para todos los municipios:
# 395.8051948051948
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2016' para todos los municipios:
# 403.3181818181818
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2017' para todos los municipios:
# 413.8831168831169
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2018' para todos los municipios:
# 424.2597402597403
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2019' para todos los municipios:
# 436.15584415584414
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_2020' para todos los municipios:
# 448.0194805194805
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2015' para todos los municipios:
# 25.474025974025974
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2016' para todos los municipios:
# 25.103896103896105
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2017' para todos los municipios:
# 25.974025974025974
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2018' para todos los municipios:
# 26.636363636363637
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2019' para todos los municipios:
# 26.11038961038961
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_b_e_industria_2020' para todos los municipios:
# 25.993506493506494
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2015' para todos los municipios:
# 58.603896103896105
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2016' para todos los municipios:
# 58.27922077922078
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2017' para todos los municipios:
# 58.4025974025974
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2018' para todos los municipios:
# 59.34415584415584
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2019' para todos los municipios:
# 61.88961038961039
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_f_construccion_2020' para todos los municipios:
# 62.62337662337662
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2015' para todos los municipios:
# 134.12337662337663
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2016' para todos los municipios:
# 132.98701298701297
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2017' para todos los municipios:
# 133.7987012987013
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2018' para todos los municipios:
# 135.27272727272728
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2019' para todos los municipios:
# 136.56493506493507
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_comercio_transporte_hosteleria_2020' para todos los municipios:
# 137.83766233766235
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2015' para todos los municipios:
# 8.616883116883116
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2016' para todos los municipios:
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# 8.941558441558442
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2017' para todos los municipios:
# 9.506493506493506
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2018' para todos los municipios:
# 9.831168831168831
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2019' para todos los municipios:
# 10.194805194805195
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_j_informacion_comunicaciones_2020' para todos los municipios:
# 10.688311688311689
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2015' para todos los municipios:
# 6.4480519480519485
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2016' para todos los municipios:
# 7.0519480519480515
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2017' para todos los municipios:
# 7.759740259740259
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2018' para todos los municipios:
# 8.311688311688311
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2019' para todos los municipios:
# 8.474025974025974
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_k_actividades_financieras_seguros_2020' para todos los municipios:
# 8.7987012987013
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2015' para todos los municipios:
# 13.577922077922079
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2016' para todos los municipios:
# 14.733766233766234
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2017' para todos los municipios:
# 15.818181818181818
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2018' para todos los municipios:
# 16.48701298701299
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2019' para todos los municipios:
# 16.38961038961039
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_l_actividades_inmobiliarias_2020' para todos los municipios:
# 17.350649350649352
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2015' para todos los municipios:
# 66.5
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2016' para todos los municipios:
# 69.31818181818181
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2017' para todos los municipios:
# 71.18181818181819
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2018' para todos los municipios:
# 73.27922077922078
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2019' para todos los municipios:
# 76.91558441558442
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_actividades_profesionales_tecnicas_2020' para todos los municipios:
# 78.96103896103897
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2015' para todos los municipios:
# 28.116883116883116
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2016' para todos los municipios:
# 29.77922077922078
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2017' para todos los municipios:
# 31.961038961038962
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2018' para todos los municipios:
# 33.564935064935064
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2019' para todos los municipios:
# 34.577922077922075
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_educacion_sanidad_servicios_sociales_2020' para todos los municipios:
# 36.785714285714285
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2015' para todos los municipios:
# 27.714285714285715
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2016' para todos los municipios:
# 29.350649350649352
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2017' para todos los municipios:
# 30.75974025974026
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2018' para todos los municipios:
# 31.337662337662337
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2019' para todos los municipios:
# 33.5974025974026
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_otros_servicios_personales_2020' para todos los municipios:
# 36.01298701298701
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2015' para todos los municipios:
# 169.64935064935065
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2016' para todos los municipios:
# 179.23376623376623
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2017' para todos los municipios:
# 187.9935064935065
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2018' para todos los municipios:
# 195.01298701298703
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2019' para todos los municipios:
# 203.53246753246754
# **************************************************
#
#
# **************************************************
# Media de 'nempresas_total_servicios_2020' para todos los municipios:
# 213.44805194805195
# **************************************************
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
# <ipython-input-29-c16a39c97c1e>:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_final[new_col] = df_final[col] / mean_total if mean_total != 0 else 0
#    ID          Municipio  Poblacion Variacion_Poblacion  Cluster_Poblacion  \
# 0  14       Acebeda (La)         55                4,03                  2
# 1  29            Ajalvir       4793               64,92                  0
# 2  35  Alameda del Valle        248               18,18                  2
# 3  40         Alamo (El)       9946              134,71                  0
# 4  88   Aldea del Fresno       3078              225,67                  2
#
#    Densidad Variacion_Densidad  Cluster_Densidad  Distancia  \
# 0      3.06               6,14                 0     88.477
# 1    246.21              94,41                 3     34.911
# 2     10.68              21,43                 0     92.242
# 3    467.88              83,00                 2     42.104
# 4     65.93             132,30                 0     56.001
#
#   Variacion_Distancia  ...  \
# 0              102,77  ...
# 1              104,66  ...
# 2              107,14  ...
# 3               88,22  ...
# 4               91,07  ...
#
#    Variacion_nempresas_otros_servicios_personales_2017_totalcomunidad  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,00
# 3                                               1,92
# 4                                               0,00
#
#    Variacion_nempresas_otros_servicios_personales_2018_totalcomunidad  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,00
# 3                                               2,04
# 4                                               0,00
#
#   Variacion_nempresas_otros_servicios_personales_2019_totalcomunidad  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,00
# 3                                               1,85
# 4                                               0,00
#
#    Variacion_nempresas_otros_servicios_personales_2020_totalcomunidad  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,00
# 3                                               1,83
# 4                                               0,00
#
#    Variacion_nempresas_total_servicios_2015_totalcomunidad  \
# 0                                               0,00
# 1                                               0,95
# 2                                               0,00
# 3                                               1,22
# 4                                               0,25
#
#    Variacion_nempresas_total_servicios_2016_totalcomunidad  \
# 0                                               0,00
# 1                                               1,05
# 2                                               0,00
# 3                                               1,21
# 4                                               0,30
#
#    Variacion_nempresas_total_servicios_2017_totalcomunidad  \
# 0                                               0,00
# 1                                               1,04
# 2                                               0,00
# 3                                               1,28
# 4                                               0,31
#
#    Variacion_nempresas_total_servicios_2018_totalcomunidad  \
# 0                                               0,00
# 1                                               1,05
# 2                                               0,00
# 3                                               1,23
# 4                                               0,28
#
#    Variacion_nempresas_total_servicios_2019_totalcomunidad  \
# 0                                               0,00
# 1                                               1,00
# 2                                               0,00
# 3                                               1,20
# 4                                               0,30
#
#    Variacion_nempresas_total_servicios_2020_totalcomunidad
# 0                                               0,00
# 1                                               0,99
# 2                                               0,00
# 3                                               1,19
# 4                                               0,33
#
# [5 rows x 518 columns]
#   Indicador      Media
# 0  pib_2015   96244.83
# 1  pib_2016  101286.91
# 2  pib_2017  105698.94
# 3  pib_2018  109207.38
# 4  pib_2019  115447.81

# %% [markdown]
# # Exportar csv

# %%
base_path = '/content/drive/My Drive/Colab Notebooks/checkpoint_2/'

df_1.to_csv(base_path + '1-población-35-cluster-variacion.csv', sep=';', encoding='utf-8')
df_2.to_csv(base_path + '2-densidad-35-cluster-variacion.csv', sep=';', encoding='utf-8')
df_3.to_csv(base_path + '3-distancia-35-cluster-variacion.csv', sep=';', encoding='utf-8')
df_final.to_csv(base_path + 'data.csv', sep=';', encoding='utf-8')

# Guardar el DataFrame df_medias en un archivo CSV
df_medias_cluster.to_csv(base_path + 'medias_indicadores_cluster.csv', sep=';', encoding='utf-8', index=False)
df_medias_comunidad.to_csv(base_path + 'medias_indicadores_comunidad.csv', sep=';', encoding='utf-8', index=False)
